# %% [markdown]
# <a href="https://colab.research.google.com/github/muskum09ari/pcos_ml/blob/main/datacleaning_more_incoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7205da1c-48b9-459e-bf3a-10ba51613da1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7205da1c-48b9-459e-bf3a-10ba51613da1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df=pd.read_csv(io.StringIO(uploaded['cleaned_file_pcos.csv'].decode('utf-8')),sep=':')
df
# Out:
#     ,Sl. No,Patient File No.,PCOS (Y/N), Age (yrs),Weight (Kg),Height(Cm) ,BMI,Blood Group,Pulse rate(bpm) ,RR (breaths/min),Hb(g/dl),Cycle(R/I),Cycle length(days),Marraige Status (Yrs),Pregnant(Y/N),No. of aborptions,  I   beta-HCG(mIU/mL),II    beta-HCG(mIU/mL),FSH(mIU/mL),LH(mIU/mL),FSH/LH,Hip(inch),Waist(inch),Waist  \
# 0    0,1,1,0,28,44.6,152,19.3,15,78,22,10.48,2,5,7,...
# 1    1,2,2,0,36,65,161.5,19.3384106,15,74,20,11.7,2...
# 2    2,3,3,1,33,68.8,165,19.37682119,11,72,18,11.8,...
# 3    3,4,4,0,37,65,148,19.41523179,13,72,20,12,2,5,...
# 4    4,5,5,0,25,52,161,19.45364238,11,72,18,10,2,5,...
# ..                                                 ...
# 536  536,537,537,0,35,50,164.592,18.5,17,72,16,11,2...
# 537  537,538,538,0,30,63.2,158,25.3,15,72,18,10.8,2...
# 538  538,539,539,0,36,54,152,23.4,13,74,20,10.8,2,6...
# 539  539,540,540,0,27,50,150,22.2,15,74,20,12,4,2,2...
# 540  540,541,541,1,23,82,165,30.1,13,80,20,10.2,4,7...
#
# ...

# %%
df.isnull()
# Out:
#      ,Sl. No,Patient File No.,PCOS (Y/N), Age (yrs),Weight (Kg),Height(Cm) ,BMI,Blood Group,Pulse rate(bpm) ,RR (breaths/min),Hb(g/dl),Cycle(R/I),Cycle length(days),Marraige Status (Yrs),Pregnant(Y/N),No. of aborptions,  I   beta-HCG(mIU/mL),II    beta-HCG(mIU/mL),FSH(mIU/mL),LH(mIU/mL),FSH/LH,Hip(inch),Waist(inch),Waist  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 536                                              False
# 537                                              False
# 538                                              False
# 539                                              False
# 540                                              False
#
# ...

# %%
df.isnull().sum()
# Out:
# ,Sl. No,Patient File No.,PCOS (Y/N), Age (yrs),Weight (Kg),Height(Cm) ,BMI,Blood Group,Pulse rate(bpm) ,RR (breaths/min),Hb(g/dl),Cycle(R/I),Cycle length(days),Marraige Status (Yrs),Pregnant(Y/N),No. of aborptions,  I   beta-HCG(mIU/mL),II    beta-HCG(mIU/mL),FSH(mIU/mL),LH(mIU/mL),FSH/LH,Hip(inch),Waist(inch),Waist                    0
# Hip Ratio,TSH (mIU/L),AMH(ng/mL),PRL(ng/mL),Vit D3 (ng/mL),PRG(ng/mL),RBS(mg/dl),Weight gain(Y/N),hair growth(Y/N),Skin darkening (Y/N),Hair loss(Y/N),Pimples(Y/N),Fast food (Y/N),Reg.Exercise(Y/N),BP _Systolic (mmHg),BP _Diastolic (mmHg),Follicle No. (L),Follicle No. (R),Avg. F size (L) (mm),Avg. F size (R) (mm),Endometrium (mm)    541
# dtype: int64

# %%
missing_values=["#NAME?",np.nan]
df=pd.read_csv("cleaned_file_pcos.csv",na_values=missing_values)

df
# Out:
#      Unnamed: 0  Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  \
# 0             0       1                 1           0          28
# 1             1       2                 2           0          36
# 2             2       3                 3           1          33
# 3             3       4                 4           0          37
# 4             4       5                 5           0          25
# ..          ...     ...               ...         ...         ...
# 536         536     537               537           0          35
# 537         537     538               538           0          30
# 538         538     539               539           0          36
# 539         539     540               540           0          27
# 540         540     541               541           1          23
#
#      Weight (Kg)  Height(Cm)         BMI  Blood Group  Pulse rate(bpm)   ...  \
# 0           44.6      152.000  19.300000           15                78  ...
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Sl. No                    0
# Patient File No.          0
# PCOS (Y/N)                0
#  Age (yrs)                0
# Weight (Kg)               0
# Height(Cm)                0
# BMI                       0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Marraige Status (Yrs)     0
# Pregnant(Y/N)             0
# No. of aborptions         0
#   I   beta-HCG(mIU/mL)    0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# FSH/LH                    0
# Hip(inch)                 0
# Waist(inch)               0
# Waist:Hip Ratio           0
# TSH (mIU/L)               0
# AMH(ng/mL)                0
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# ...

# %%
df.isnull().any()
# Out:
# Unnamed: 0                False
# Sl. No                    False
# Patient File No.          False
# PCOS (Y/N)                False
#  Age (yrs)                False
# Weight (Kg)               False
# Height(Cm)                False
# BMI                       False
# Blood Group               False
# Pulse rate(bpm)           False
# RR (breaths/min)          False
# Hb(g/dl)                  False
# Cycle(R/I)                False
# Cycle length(days)        False
# Marraige Status (Yrs)     False
# Pregnant(Y/N)             False
# No. of aborptions         False
#   I   beta-HCG(mIU/mL)    False
# II    beta-HCG(mIU/mL)    False
# FSH(mIU/mL)               False
# LH(mIU/mL)                False
# FSH/LH                    False
# Hip(inch)                 False
# Waist(inch)               False
# Waist:Hip Ratio           False
# TSH (mIU/L)               False
# AMH(ng/mL)                False
# PRL(ng/mL)                False
# Vit D3 (ng/mL)            False
# ...

# %%
df
# Out:
#      Unnamed: 0  Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  \
# 0             0       1                 1           0          28
# 1             1       2                 2           0          36
# 2             2       3                 3           1          33
# 3             3       4                 4           0          37
# 4             4       5                 5           0          25
# ..          ...     ...               ...         ...         ...
# 536         536     537               537           0          35
# 537         537     538               538           0          30
# 538         538     539               539           0          36
# 539         539     540               540           0          27
# 540         540     541               541           1          23
#
#      Weight (Kg)  Height(Cm)         BMI  Blood Group  Pulse rate(bpm)   ...  \
# 0           44.6      152.000  19.300000           15                78  ...
# ...

# %%
#df=df.drop("Unnamed: 45",axis=1)
#print(df.columns)
'''df.to_csv('cleaned_file_pcos.csv', encoding = 'utf-8-sig') 
files.download('cleaned_file_pcoss.csv')'''
# Out:
# "df.to_csv('cleaned_file_pcos.csv', encoding = 'utf-8-sig') \nfiles.download('cleaned_file_pcoss.csv')"

# %%
import numpy as np
import seaborn as sns

# %%
sns.heatmap(df.isnull(),yticklabels=False, annot=True)

# %%
print(df.columns)
df.to_csv('cleaned_file_pcos.csv', encoding = 'utf-8-sig') 
files.download('cleaned_file_pcos.csv')
# Out:
# Index(['Sl. No', 'Patient File No.', 'PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)',
#        'Height(Cm) ', 'BMI', 'Blood Group', 'Pulse rate(bpm) ',
#        'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)', 'Cycle length(days)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'No. of aborptions',
#        '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)', 'FSH(mIU/mL)',
#        'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio',
#        'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)',
#        'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)'],
#       dtype='object')
