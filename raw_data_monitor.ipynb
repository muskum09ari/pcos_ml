# %% [markdown]
# <a href="https://colab.research.google.com/github/muskum09ari/pcos_ml/blob/main/raw_data_monitor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3530ca34-5d4a-430c-bad9-0274ec2f6f9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3530ca34-5d4a-430c-bad9-0274ec2f6f9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df=pd.read_csv(io.StringIO(uploaded['pcos.csv'].decode('utf-8')),sep=':')
df
# Out:
#     Sl. No,Patient File No.,PCOS (Y/N), Age (yrs),Weight (Kg),Height(Cm) ,BMI,Blood Group,Pulse rate(bpm) ,RR (breaths/min),Hb(g/dl),Cycle(R/I),Cycle length(days),Marraige Status (Yrs),Pregnant(Y/N),No. of aborptions,  I   beta-HCG(mIU/mL),II    beta-HCG(mIU/mL),FSH(mIU/mL),LH(mIU/mL),FSH/LH,Hip(inch),Waist(inch),Waist  \
# 0    1,1,0,28,44.6,152,19.3,15,78,22,10.48,2,5,7,0,...
# 1    2,2,0,36,65,161.5,#NAME?,15,74,20,11.7,2,5,11,...
# 2    3,3,1,33,68.8,165,#NAME?,11,72,18,11.8,2,5,10,...
# 3    4,4,0,37,65,148,#NAME?,13,72,20,12,2,5,4,0,0,1...
# 4    5,5,0,25,52,161,#NAME?,11,72,18,10,2,5,1,1,0,8...
# ..                                                 ...
# 536  537,537,0,35,50,164.592,18.5,17,72,16,11,2,5,8...
# 537  538,538,0,30,63.2,158,25.3,15,72,18,10.8,2,5,4...
# 538  539,539,0,36,54,152,23.4,13,74,20,10.8,2,6,8,0...
# 539  540,540,0,27,50,150,22.2,15,74,20,12,4,2,2,0,0...
# 540  541,541,1,23,82,165,30.1,13,80,20,10.2,4,7,2,0...
#
# ...

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of      Sl. No,Patient File No.,PCOS (Y/N), Age (yrs),Weight (Kg),Height(Cm) ,BMI,Blood Group,Pulse rate(bpm) ,RR (breaths/min),Hb(g/dl),Cycle(R/I),Cycle length(days),Marraige Status (Yrs),Pregnant(Y/N),No. of aborptions,  I   beta-HCG(mIU/mL),II    beta-HCG(mIU/mL),FSH(mIU/mL),LH(mIU/mL),FSH/LH,Hip(inch),Waist(inch),Waist  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 536                                              False
# 537                                              False
# 538                                              False
# 539                                              False
# ...

# %%
missing_values=["#NAME?",np.nan]
df=pd.read_csv("pcos.csv",na_values=missing_values)

# %%
df.isnull().sum()
# Out:
# Sl. No                      0
# Patient File No.            0
# PCOS (Y/N)                  0
#  Age (yrs)                  0
# Weight (Kg)                 0
# Height(Cm)                  0
# BMI                       299
# Blood Group                 0
# Pulse rate(bpm)             0
# RR (breaths/min)            0
# Hb(g/dl)                    0
# Cycle(R/I)                  0
# Cycle length(days)          0
# Marraige Status (Yrs)       1
# Pregnant(Y/N)               0
# No. of aborptions           0
#   I   beta-HCG(mIU/mL)      0
# II    beta-HCG(mIU/mL)      0
# FSH(mIU/mL)                 0
# LH(mIU/mL)                  0
# FSH/LH                    532
# Hip(inch)                   0
# Waist(inch)                 0
# Waist:Hip Ratio           532
# TSH (mIU/L)                 0
# AMH(ng/mL)                  0
# PRL(ng/mL)                  0
# Vit D3 (ng/mL)              0
# PRG(ng/mL)                  0
# RBS(mg/dl)                  0
# Weight gain(Y/N)            0
# ...

# %%
df.isnull().any()
# Out:
# Sl. No                    False
# Patient File No.          False
# PCOS (Y/N)                False
#  Age (yrs)                False
# Weight (Kg)               False
# Height(Cm)                False
# BMI                        True
# Blood Group               False
# Pulse rate(bpm)           False
# RR (breaths/min)          False
# Hb(g/dl)                  False
# Cycle(R/I)                False
# Cycle length(days)        False
# Marraige Status (Yrs)      True
# Pregnant(Y/N)             False
# No. of aborptions         False
#   I   beta-HCG(mIU/mL)    False
# II    beta-HCG(mIU/mL)    False
# FSH(mIU/mL)               False
# LH(mIU/mL)                False
# FSH/LH                     True
# Hip(inch)                 False
# Waist(inch)               False
# Waist:Hip Ratio            True
# TSH (mIU/L)               False
# AMH(ng/mL)                False
# PRL(ng/mL)                False
# Vit D3 (ng/mL)            False
# PRG(ng/mL)                False
# ...

# %%
import numpy as np
import seaborn as sns

# %%
sns.heatmap(df.isnull(),yticklabels=False, annot=True) # it shows the erros

# %% [markdown]
# detecting na values

# %% [markdown]
# Handling problem

# %% [markdown]
# steps to remove na values

# %%
df # it willl print data frame
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0         1                 1           0          28         44.6
# 1         2                 2           0          36         65.0
# 2         3                 3           1          33         68.8
# 3         4                 4           0          37         65.0
# 4         5                 5           0          25         52.0
# ..      ...               ...         ...         ...          ...
# 536     537               537           0          35         50.0
# 537     538               538           0          30         63.2
# 538     539               539           0          36         54.0
# 539     540               540           0          27         50.0
# 540     541               541           1          23         82.0
#
#      Height(Cm)    BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0        152.000  19.3           15                78                22  ...
# ...

# %%
df.fillna(method='ffill') #forward filling
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0         1                 1           0          28         44.6
# 1         2                 2           0          36         65.0
# 2         3                 3           1          33         68.8
# 3         4                 4           0          37         65.0
# 4         5                 5           0          25         52.0
# ..      ...               ...         ...         ...          ...
# 536     537               537           0          35         50.0
# 537     538               538           0          30         63.2
# 538     539               539           0          36         54.0
# 539     540               540           0          27         50.0
# 540     541               541           1          23         82.0
#
#      Height(Cm)    BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0        152.000  19.3           15                78                22  ...
# ...

# %%
df.fillna(method='bfill') # backward filling
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0         1                 1           0          28         44.6
# 1         2                 2           0          36         65.0
# 2         3                 3           1          33         68.8
# 3         4                 4           0          37         65.0
# 4         5                 5           0          25         52.0
# ..      ...               ...         ...         ...          ...
# 536     537               537           0          35         50.0
# 537     538               538           0          30         63.2
# 538     539               539           0          36         54.0
# 539     540               540           0          27         50.0
# 540     541               541           1          23         82.0
#
#      Height(Cm)    BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0        152.000  19.3           15                78                22  ...
# ...

# %%
#interpoloation it added and divided the data
df_dropped=df.interpolate()

# %%
df_dropped
df_dropped.to_csv('cleaned_file_pcos.csv', encoding = 'utf-8-sig') 
files.download('cleaned_file_pcos.csv')
# so here file name which dropped has been interploated and saved

# %%
sns.heatmap(df_dropped.isnull(),yticklabels=False, annot=True)

# %%
df = df.drop('Unnamed: 44', axis=1)
df
missing_values=["#NAME?",np.nan]
df=pd.read_csv("pcos.csv",na_values=missing_values)
df_dropped=df.interpolate()
df_dropped
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0         1                 1           0          28         44.6
# 1         2                 2           0          36         65.0
# 2         3                 3           1          33         68.8
# 3         4                 4           0          37         65.0
# 4         5                 5           0          25         52.0
# ..      ...               ...         ...         ...          ...
# 536     537               537           0          35         50.0
# 537     538               538           0          30         63.2
# 538     539               539           0          36         54.0
# 539     540               540           0          27         50.0
# 540     541               541           1          23         82.0
#
#      Height(Cm)         BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  \
# 0        152.000  19.300000           15                78                22
# ...

# %%
df
missing_values=["#NAME?",np.nan]
df=pd.read_csv("pcos.csv",na_values=missing_values)
df_dropped=df.interpolate()

# %%
df_dropped
# Out:
# ...
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0         1                 1           0          28         44.6
# 1         2                 2           0          36         65.0
# 2         3                 3           1          33         68.8
# 3         4                 4           0          37         65.0
# 4         5                 5           0          25         52.0
# ..      ...               ...         ...         ...          ...
# 536     537               537           0          35         50.0
# 537     538               538           0          30         63.2
# 538     539               539           0          36         54.0
# 539     540               540           0          27         50.0
# 540     541               541           1          23         82.0
#
#      Height(Cm)         BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  \
# 0        152.000  19.300000           15                78                22
# ...

# %%
missing_values=["#NAME?",np.nan]
df=pd.read_csv("pcos.csv",na_values=missing_values)

# %%
df_dropped=df.interpolate()

# %%
df_dropped
# Out:
#      Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# 0         1                 1           0          28         44.6
# 1         2                 2           0          36         65.0
# 2         3                 3           1          33         68.8
# 3         4                 4           0          37         65.0
# 4         5                 5           0          25         52.0
# ..      ...               ...         ...         ...          ...
# 536     537               537           0          35         50.0
# 537     538               538           0          30         63.2
# 538     539               539           0          36         54.0
# 539     540               540           0          27         50.0
# 540     541               541           1          23         82.0
#
#      Height(Cm)         BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  \
# 0        152.000  19.300000           15                78                22
# ...

# %%
df_dropped.isnull().any()
# Out:
# Sl. No                    False
# Patient File No.          False
# PCOS (Y/N)                False
#  Age (yrs)                False
# Weight (Kg)               False
# Height(Cm)                False
# BMI                       False
# Blood Group               False
# Pulse rate(bpm)           False
# RR (breaths/min)          False
# Hb(g/dl)                  False
# Cycle(R/I)                False
# Cycle length(days)        False
# Marraige Status (Yrs)     False
# Pregnant(Y/N)             False
# No. of aborptions         False
#   I   beta-HCG(mIU/mL)    False
# II    beta-HCG(mIU/mL)    False
# FSH(mIU/mL)               False
# LH(mIU/mL)                False
# FSH/LH                     True
# Hip(inch)                 False
# Waist(inch)               False
# Waist:Hip Ratio            True
# TSH (mIU/L)               False
# AMH(ng/mL)                False
# PRL(ng/mL)                False
# Vit D3 (ng/mL)            False
# PRG(ng/mL)                False
# ...

# %%
sns.heatmap(df_dropped.isnull(),yticklabels=False, annot=True)
